# %% [markdown]
# <a href="https://colab.research.google.com/github/anthng/sentiment140/blob/master/Vietnamese_SA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive/')
os.chdir('/content/drive/My Drive/BERT/SA')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Sun Jul 19 05:36:36 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    12W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (3.0.2)
# Requirement already satisfied: tokenizers==0.8.1.rc1 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8.1rc1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.1.91)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)

# %%
# !pip install fastBPE
# !pip install fairseq
# Out:
# Requirement already satisfied: fastBPE in /usr/local/lib/python3.6/dist-packages (0.1.0)
# Requirement already satisfied: fairseq in /usr/local/lib/python3.6/dist-packages (0.9.0)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.4.12)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from fairseq) (0.29.21)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fairseq) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.18.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from fairseq) (2019.12.20)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.5.1+cu101)
# Requirement already satisfied: cffi in /usr/local/lib/python3.6/dist-packages (from fairseq) (1.14.0)
# Requirement already satisfied: mecab-python3==0.996.5 in /usr/local/lib/python3.6/dist-packages (from sacrebleu->fairseq) (0.996.5)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/dist-packages (from sacrebleu->fairseq) (1.7.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->fairseq) (0.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi->fairseq) (2.20)

# %%
# Install the vncorenlp python wrapper
# !pip install vncorenlp

# Download VnCoreNLP-1.1.1.jar & its word segmentation component (i.e. RDRSegmenter) 
# !mkdir -p vncorenlp/models/wordsegmenter
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
# !mv VnCoreNLP-1.1.1.jar vncorenlp/ 
# !mv vi-vocab vncorenlp/models/wordsegmenter/
# !mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/
# Out:
# Requirement already satisfied: vncorenlp in /usr/local/lib/python3.6/dist-packages (1.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from vncorenlp) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->vncorenlp) (2020.6.20)

# %%
from vncorenlp import VnCoreNLP
rdrsegmenter = VnCoreNLP("/content/drive/My Drive/BERT/SA/vncorenlp/VnCoreNLP-1.1.1.jar", annotators="wseg", max_heap_size='-Xmx500m') 

text = "Đại học Bách Khoa Hà Nội."

word_segmented_text = rdrsegmenter.tokenize(text) 
print(word_segmented_text)
# Out:
# [['Đại_học', 'Bách_Khoa', 'Hà_Nội', '.']]

# %%
# !wget https://public.vinai.io/PhoBERT_base_transformers.tar.gz
# !tar -xzvf PhoBERT_base_transformers.tar.gz

# %%
# !wget https://public.vinai.io/PhoBERT_base_fairseq.tar.gz
# !tar -xzvf PhoBERT_base_fairseq.tar.gz

# %%
from fairseq.data.encoders.fastbpe import fastBPE
from fairseq.data import Dictionary
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('--bpe-codes', 
    default="/content/drive/My Drive/BERT/SA/PhoBERT_base_transformers/bpe.codes",
    required=False,
    type=str,
    help='path to fastBPE BPE'
)
args, unknown = parser.parse_known_args()
bpe = fastBPE(args)

# Load the dictionary
vocab = Dictionary()
vocab.add_from_file("/content/drive/My Drive/BERT/SA/PhoBERT_base_transformers/dict.txt")

# %%
bpe.encode("Hôm_nay trời nóng quá nên tôi ở nhà viết Viblo!")
# Out:
# 'Hôm_nay trời nóng quá nên tôi ở nhà viết Vi@@ blo@@ !'

# %%
vocab.encode_line('<s> ' + 'Hôm_nay trời nóng quá nên tôi ở nhà viết Vi@@ blo@@ !' + ' </s>')
# Out:
# tensor([    0,  3791,  1027,   898,   204,    77,    70,    25,    69,   467,
#          3696, 16856,   381,     2,     2], dtype=torch.int32)

# %%
import re

train_path = '/content/drive/My Drive/BERT/SA/train.crash'
test_path = '/content/drive/My Drive/BERT/SA/test.crash'

train_id, train_text, train_labels = [], [], []
test_id, test_text = [], []

with open(train_path, 'r') as f_r:
    data = f_r.read().strip()

    data = re.findall('train_[\s\S]+?\"\n[01]\n\n', data)

    for sample in data:
        splits = sample.strip().split('\n')

        id = splits[0]
        label = int(splits[-1])
        text = ' '.join(splits[1:-1])[1:-1]
        text = rdrsegmenter.tokenize(text)
        text = ' '.join([' '.join(x) for x in text])

        train_id.append(id)
        train_text.append(text)
        train_labels.append(label)


with open(test_path, 'r') as f_r:
    data = f_r.read().strip()
    data = re.findall('train_[\s\S]+?\"\n[01]\n\n', data)

    for sample in data:
        splits = sample.strip().split('\n')

        id = splits[0]
        text = ' '.join(splits[1:])[1:-1]
        text = rdrsegmenter.tokenize(text)
        text = ' '.join([' '.join(x) for x in text])

        test_id.append(id)
        test_text.append(text)

# %%
train_text
# Out:
# ['Dung dc sp tot cam on shop Đóng_gói sản_phẩm rất đẹp và chắc_chắn Chất_lượng sản_phẩm tuyệt_vời',
#  'Chất_lượng sản_phẩm tuyệt_vời . _Son mịn nhưng khi đánh lên không như màu trên ảnh',
#  'Chất_lượng sản_phẩm tuyệt_vời nhưng k có hộp k có dây giày đen k có tất',
#  ': ( ( Mình hơi thất_vọng 1 chút vì mình đã kỳ_vọng cuốn sách khá nhiều hi_vọng nó sẽ nói về việc học_tập của cách sinh_viên trường Harvard ra sao những nỗ_lực của họ như_thế_nào 4h sáng ? tại_sao họ lại phải thức dậy vào thời_khắc đấy ? sau đó là cả một câu_chuyện ra sao . Cái mình thực_sự cần ở đây là câu_chuyện ẩn dấu trong đó để tự bản_thân mỗi người cảm_nhận và đi_sâu vào lòng người hơn . Còn cuốn sách này chỉ đơn_thuần là cuốn sách dạy kĩ_năng mà hầu_như sách nào cũng đã có . BUồn ...',
#  'Lần trước mình mua áo_gió màu hồng rất ok mà đợt này lại giao 2 cái áo_gió chất khác như vải mưa ý : ( (',
#  'Chất_lượng sản_phẩm tuyệt_vời có_điều không cứng_cáp với không cố_định dáng nói_chung đẹp hợp túi_tiền',
#  'Đã nhận đc hàng rất nhanh mới đặt buổi tối mà trưa mai là có rồi = } } Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt',
#  'Các siêu phẩm thấy cấu_hình toàn tựa tựa nhau . Ko còn sự đột_phá lớn nữa . Chỉ là nâng_cấp . Khác nhau về kiểu_dáng . Htc này vs giá trên thật lòng khó cạnh_tranh mạnh vs siêu phẩm khác , chỉ dành cho fan của họ thôi .',
#  'Hàng ship nhanh chất_lượng tốt tư_vấn nhiệt_tình ship rất đung size sẽ ủng_hộ shop nhìu ❤️',
#  'Đồng_hồ đẹp nhưng 1 cái đứt dây 1 cái k chạy mua ve phải sửa',
#  'Chất_lượng sản_phẩm tuyệt vời.y hình chụp.đáng tiền',
#  'Hjhj shop giao hàng nhanh quá . Đẹp lắm ạ bé nhà m rất thích',
#  '" nhìn đẹp phết nhỉ .. "',
#  'Đóng_gói rất đẹp . Chất_lượng sản_phẩm rất tốt Chất_lượng sản_phẩm tuyệt_vời',
#  'Săn đc với giá 11k . Toẹt vời',
#  'OK rất hài_lòng',
#  'Giao thiếu mình cái này rồi shop ơi T ^ T',
#  'Chất_lượng sản_phẩm tuyệt_vời tôi rất thích',
#  'Giày đẹp lắm có_điều dây hơi ngắn tí ạ\xa0 Chất_lượng sản_phẩm tuyệt_vời',
#  'Yếm vải đẹp nhưng ít mẫu đẹp',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Rất đáng tiền Rất đáng tiền . Giao hàng hôm sau là có',
#  'không hài_lòng sản_phẩm cho lắm . giặt lan đầu_tiên da nhoe màu hết rồi .',
#  'Giao hàng nhanh , mặc đẹp Cám_ơn shop',
#  'Chất_lượng sản_phẩm tuyệt_vời bao_bì cute phô_mai que_son đánh mịn cực không có bị bột à còn giao hành max nhanh luôn',
#  'Đồng_hồ thì đẹp thật . Nhưng tại_sao kim lúc chạy lúc đứng . Nhắn_tin thì ko trả_lời . Mấy bạn lưu_ý đừng mua nữa .',
#  'Giao hàng siêu nhanh . Đóng_gói cẩn_thận và tư_vấn nhiệt_tình . Hạt điều thấm vị và giòn .',
#  '" Cũng hơi bất_tiện xu_thế này e rằng đa phằn người dùng sẽ không ưa_thích "',
#  'Toàn hàng trungkhi mua quên ko coi kĩ',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn . Được shop tặng thêm quà nữa 😘',
#  'Hôm_nay chiên thử cá_hồi , cá_chiên ăn ngọt hơn chiên kiểu truyền_thống vì giữ đc nước\xa0 Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  '" máy này có cái CPU k phải skylake là thấy không hay rồi "',
#  'Hàng vận_chuyển bị nứt mẻ 1 góc.chất lượng ok .',
#  'Sạc tự_động ngắt pin',
#  'Shop giao hàng kh giống màu',
#  'Shop giao sai màu đặt màu xanh da_trời shop giao màu nõn chuối . Đặc_biệt sản_phẩm đã sai màu còn bị vỡ phần nắp và chốt ko sd được . Chat shop ko tl đến lúc khách nhấn hoàn hàng mới tl sơ_sài và ko đồng_ý hoàn . Rất thất_vọng về cách làm_việc của Shop . May_mà Shopee lấy lại công_bằng và hoàn tiền . \xa0',
#  'khong thay den sang',
#  'So với giá thì chất_lượng tuyệt_vời . capo khá chắc_chắn và đẹp',
#  'Không cầm pin . Không sử_dụng được \xa0Chất lượng sản_phẩm rất kém',
#  'Những nước phát_triển hàng trăm_năm cũng không ai làm tầng ngầm dưới đường_cao_tốc cả , xe_điện_ngầm ra ngoại_ô cũng thành nổi để tiết_kiệm chi_phí .',
#  'Shop phục_vụ rất tốt . \xa0 Thời_gian giao hàng rất nhanh',
#  'Sản_phẩm tốt hỗ_trợ khách_hàng nhiệt_tình',
#  'Giày đẹp mang êm và vừa chân lắm nha shop .',
#  'Chất_liệu và kiểu_dáng thì được nhưng quần hơi ngắn',
#  'hàng bị lỗi nhiều quá màn_hình cháy phim bị bong',
#  'Chất_lượng sản_phẩm tuyệt_vời Thời_gian giao hàng rất nhanh ngon sẽ ủng_hộ shop dài_dài ...',
#  'Chưa dùng nhưng nghe bạn m dùng r fb chất_lượng khá tốt serum thơm mùu bưởi . Có 1 góp_ý là shop nên thay lọ đựng sang loại khác vì bọn m mua nhiều lần thấy hầu_hết các lọ vòi xịt đều k ổn .',
#  'Uống rất ngon Giao hàng nhanh Chất_lượng sản_phẩm tuyệt_vời ..................... 😋😋😋😋 ......................',
#  'Shop bảo làm theo yêu_cầu theo yêu_cầu là phải có cao_su chống trượt mà không theo yêu_cầu thôi nhịn đắng cục tức vậy . Các bạn mua nên chú_ý sẵn không lại ngậm cục tức như mình di bị rơi mấy lần lại lôi kê tay cũ ra xài',
#  'Rẻ lầm chất_lượng lém',
#  'Huỷ trước khi shop giao cho ship để đổi màu mà shop k nhận đơn huỷ vẫn cố giao !',
#  'Đóng_gói sản_phẩm rất kémTư vấn k nhiệt_tình',
#  'Sản_phẩm tốt ưng_ý !',
#  'E xay đá mà bị gãy ko xay dc ạ',
#  'Sản_phẩm rất đẹp . Y hình và chất_lượng rất tuyệt_vời . Mik mua một lúc 5 đôi luôn . Mik sẽ ủng_hộ shop dài dài\xa0',
#  'Sản_phẩm không an_toàn quá nguy_hiểm cho người sử_dụng . Không đáng để mua sp này . Quá sai_lầm khi mua',
#  'Thời_gian giao hàng lâu . Đặt mũ len mèo màu ghi xám lại giao màu vàng . Khẩu_trang xô mỏng tang.K biết có phải do giá sale k mà chất_lượng chán thế .',
#  'Chất_lượng sản_phẩm tuyệt_vời Hơi cũ tí nhưng mượt lắm thanks shop',
#  'Sản_phẩm k như mình mong_đợi .. k cài dc đồ_chơi vào .. ghế hơi bất_tiện khi sử_dụng',
#  'Hôm_nay tình_cờ đọc được bài viết của bạn mình cảm_thấy rất vui .',
#  'Đóng_gói sản_phẩm rất chắc_chắn . Sản_phẩm rất dày_dặn . Thời_gian giao hàng rất nhanh .',
#  'Áo vs giày siêu yêu ạ',
#  'mang đi công_tác rất tiện_lợi dùng rất mượt ko lo bị trầy_xước',
#  'Chất_lượng quá kém giao hàng không đúng mẫu . Khuyên mọi người không nên mua hàng của shop\xa0',
#  'Đặt lần 2 rồi mà giao hàng lâu quá vậy ? ? ?',
#  'Khăn dày đẹp .',
#  'Đặt tat bé giao tat nguoi lon . giao lộn hỏi k tl',
#  'Mình thoa vào ngọn tóc thấy tóc bị rít nên chỉ thoa vào phần chân mùi thơm',
#  '- Giao hàng rất nhanh < 3 < 3 gói hàng siêu kĩ luôn -_Son thơm mùi sữa cacao ghiền luôn á = 3333 vỏ_son nhìn cưng ghê màu_son siêu đẹp chất_son rất lì như_son kem nên dưỡng kĩ môi vs tẩy tbc mới đánh xinh đc = ) ) )',
#  'Đánh 1 * vì không có 0 * . Đặt 3 gói Monny L44 tt thẻ ở tp HCM nhưng 1 tuần mới nhận đc gói hàng bằng 1 túi nilong do người_nhà nhận dùm khi mình kiểm_tra thì thấy có 1 gói nên yc hoàn tiền và yc gọi dt yc shop giao 2 gói thiếu shop hứa và đợi đến ngày cuối_cùng gửi trả hàng thì không thấy đâu .',
#  'Thời_gian giao hàng rất nhanh shop phuc vụ quá qua tệ hang \xa0bị hư_hại ma hong lời giai quyết . người khác da the ma nguoi kia cũng vay hong chu_đáo can xem xet lại khi mau hàng shop nay nha cac ban',
#  'Đẹp thích hết',
#  'Kem dùng ổn mỗi_tội hơi tối do với da mình',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn chất_lượng sản_phẩm tốt',
#  'Good value for money Good value for money Fast delivery Excellent service by seller',
#  'Chất_lượng sản_phẩm tốt Đóng_gói sản_phẩm rất cẩn_thận và chắc_chắn Thời_gian giao hàng rất nhanh',
#  'Chị chủ tư_vấn rất nhiệt_tình 😆😆 hình_dáng và chất_lượng sản_phẩm tuyệt_vời',
#  'SHOP ĐĂNG ẢNH MỘT ĐẰNG SẢN_PHẨM MỘT LẺO . BÁN CÁP THÌ ÚP HÌNH CÁI CÁP THÔI CHỨ UP CẢ_CỤC SẠC GÂY NHẦM_LẪN CHO KHÁCH_HÀNG LÀ COMBO CÁP + DÂY SẠC . TÔI MUA LIỀN 2 CÁI LÚC NHẬN HÀNG MỚI NGỚ NGƯỜI RA BỊ MUA ĐẮT . CHẤT_LƯỢNG SẢN_PHẨM CHƯA RÕ .',
#  'Chất_lượng sản_phẩm tuyệt_vời . Shop tư_vấn nhiệt_tình ạ < 3 sẽ ủng_hộ shop dài_dài .',
#  'Poor delivery speed Poor product quality',
#  'Đúng là tiền nào của đó ko ngon mùi kì kì ko thơm như lạp_xưởng bình_thường ! Thất_vọng vô_cùng ! ! !',
#  'Chất_lượng sản_phẩm tuyệt_vời . Đóng_gói sản_phẩm rất đẹp và chắc chắncám ơn shop đã tặng quà sẽ ủng_hộ tiếp ...',
#  'Giày_Ok lắm shop ship hàng nhanh nữa ❤️',
#  'Chất_lượng sản_phẩm tuyệt vời.rất OK',
#  'Giày chắc_chắn . Đế hơi bẩn tí nhưng chắc sẽ lau được . Giao hàng nhanh',
#  'Hàng giao thiếu kêu gửi bù cho mà cả tháng chưa thấy gửi . Nhắn_tin ko trả_lời',
#  'Shop hết hàng nhưng không báo . Mình đặt 1 cặp thế_mà gởi chỉ 1 ốp kèm theo tiền ốp kja . Thanh_toán mở_hàng ra xem thì chỉ có 1 ốp và số tiền đã thanh_toán . Xài cặp thế giờ có 1 ốp thì sao đây . Mình chỉ góp_ý vậy thôi\xa0',
#  'Giao ko đúng Đồ . Tôi đã bị lừa',
#  'hk giong mẩu gì cả da vay bi lỗi nua\xa0',
#  'Tương_đối hài_lòng giày chắc_chắn êm nhưng đường may chỉ thừa còn nói_chung ok với giá này : ) thanks shop nha',
#  'Dép xinh . Chủ shop rep tn rất nhiệt_tình . Chúc shop buôn may bán đắt ạ .',
#  'Mua 2đ có 2 lỗ xỏ dây ib shop kh trả_lời giày rộng mn cân_nhắc trc khi mua . \xa0',
#  'Tốt tgian giao hàng nhanh',
#  'Nên mua nha mọi người',
#  'Thấy ghi đc tặng kèm tã quần.đến khi nhận hàng thì k thấy.hỏi shop thì nói k có .',
#  'Shop phục_vụ rất kém . Đã phải nhắn_tin hỏi cẩn_thận là còn k . Shop nói còn mà gửi màu sai . \xa0',
#  'Shop phục_vụ rất tốt . Sản_phẩm đúng với thông_tin đăng_tải .',
#  'Đặt combo mà shop chỉ giao bánh gạo và sốt k thấy phô_mai và chả cá đâucó trả lại tiền nhưng mua combo để có đầy_đủ vâyh mà thiếu chả báo gì ib thì chưa thấy trả_lời . Shop phục_vụ rất kém',
#  'Shop này uy_tín nè hàng đã đẹp mà_còn đầy_đủ hộp + pin tặng thêm đeo đồng_bọn nó hỏi mua mấy triệu he he chắc nhập hàng của shop về bán lại quá : )',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn . Hàng Giao Dung mẫu chọn . Chất vải dẹp',
#  'Sản_phẩm k như quảng_cáo là 9058 liên_hệ theo số đt của shop trên vỏ hộp gửi thì thấy tổng_đài báo : số đt không có.Hãi vãi !',
#  'Chất_lượng sản_phẩm tuyệt_vời đóng_gói sản_phẩm rất đẹp và chắc_chắn giao hàng siu nhanh chỉ có 1 điểm trừ duy_nhất là đậu_phộng không được cay cho lắm .',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Thời_gian giao hàng rất nhanh lại còn được thêm quà tặng kèm . \xa0 Shop phục_vụ rất tốt !',
#  'ngọt wá . cay wá . ướt wá tạm đc . đúng với giá tiền',
#  'Chưa xài nhưng shop nhiệt_tình giao hàng nhanh đóng_gói đẹp nên cho 5 *',
#  'Mui khoan xài mau lúc qua',
#  'Trước_mắt dùng tốt',
#  'Sản_phẩm tốt . Mẫu_mã đẹp\xa0 Chất_lượng sản_phẩm tuyệt_vời',
#  'sản_phẩm kém chất_lượng độ sáng yếu pin không cầm sáng hoài không tắt công_suất 15w thua bóng 9w nữa hàng kém chất_lượng',
#  'Sản_phẩm tốt .. Xài rất ưng_ý',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn \xa0Tuy nhiên sản_phẩm ko đc như mong_đợi của mình lắm Thời_gian giao hàng rất nhanh',
#  'Hạt_giống k nảy mầm',
#  'Chất_lượng sản_phẩm tuyệt_vời Shop phục_vụ rất tốt Rất đáng tiền Thời_gian giao hàng rất nhanh Shop có tâm máy dùng thích',
#  'rẻ hơn khi mua sieu thị nè\xa0 Chất_lượng sản_phẩm tuyệt_vời Thời_gian giao hàng rất nhanh',
#  'Sp ok lam an uy tin . Goi hang can than . Giao hang nhanh',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Rất đáng tiền Thời_gian giao hàng rất nhanh ns chung sp bên shop giá mềm hàng đẹp e sẽ ủng_hộ shop nhiều hơn😁😁',
#  'TOÀN HÀNG FAKE . MASK RẺ_TIỀN BÁN HÀNG CÓ TÂM MỘT_CHÚT ĐI',
#  'hàng ko đúng chất_lượng',
#  'Chất_lượng sản_phẩm rất kém.thô.',
#  'Chất_lượng sản_phẩm tuyệt_vời Giao hàng bao nhanh nhé dù ở tpHCM shop ngoài Đà_Nẵng nhưng chỉ mất 2 ngày kể từ lúc đặt . \xa0 Chúc shop mua may bán đắt',
#  'San_Pham tuyet voi .. Giay ray Dep .. Cho 5sao luon nha shop',
#  'mua 2 cục lap vao ko có tính hiêu . đều ko dùng được',
#  'Mình mua bộ này trong đợt sale 99k của Tiki hàng giao chậm vì bị cháy hàng thì không sao . Nhưng chất_lượng SP thì khác hoàn_toàn so với các lần mình mua trước đó ở Siêu_thị . Dầu_gội thì lỏng và không thơm như bình_thường hay dùng dầu xả thì có mùi kì_lạ chua_chua gì đó xộc lên mỗi lần lấy ra dùng.Nói chung là cảm_giác như không phải chính hãng vậy đó .',
#  'Áo đẹp . Lông mịn . \xa0Nói chung là rất ưng_ý và Rất đáng tiền',
#  'o ngon',
#  'k như QC jờ mới lắp keu rất bé dc đổi lại thì tốt .',
#  'Giày chất rất ổn giao hàng hơi lâu chút . \xa0 Đóng_gói sản_phẩm rất đẹp và chắc_chắn Rất đáng tiền',
#  'san pham khac so voi hinh mau.quan_din dau nhot.vai mong',
#  'đã mua , chưa bít kq ra sao , tuy_nhiên ko có ghi shopee ở ngoài , bên trong ok , thanks Thời_gian giao hàng rất nhanh',
#  'Shop giao hàng nhanh . _Son màu cam sáng nên chất hơi bột lên màu chuẩn và có màu bám lại sau khi chùi .',
#  'Cảm_ơn shop giao hàng rất nhanh trong 2 gói thì m thích gói khô gà lá chanh hơn khô và thơm . Sẽ ủng_hộ shop thêm Đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  '" cái này đc đấy , mình thích đồ chính hãng . "',
#  'Dong ho sai duoc',
#  'Đặt trong ảnh là lọ thuỷ_tinh không thấy thương_hiệu hay nhãn_mác . Nhưng giao là lọ nhựa hiệu hơi lạ . Nhưng không sao viên nghệ ăn dễ ngọt nghe mùi mật_ong đúng . Không chắc là hiệu_quả vì chỉ mới sử_dụng vài viên nhưng nếu có hiệu_quả lần tới sẽ mua tiếp ❤️ . \xa0',
#  'Kêu tặng 7 bịch bánh_tráng nhưng chỉ đưa 4 cục kẹo milo\xa0',
#  'Chất_lượng sản_phẩm tuyệt vời0k',
#  'Chất_lượng tốt ! 👍🏻',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Rất đáng tiền Rất đáng tiền Thời_gian giao hàng rất nhanh Thời_gian giao hàng rất nhanh Rất đáng tiền Shop phục_vụ rất tốt Shop phục_vụ rất tốt Rất đáng tiền Chất_lượng sản_phẩm tuyệt_vời',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn . Khá ok',
#  'Mk mua sz 41 mà giao nhầm sz rộng ko đi đc😡',
#  'Chất_lượng sản_phẩm tốt \xa0đóng gói sản_phẩm cẩn_thận',
#  'Túi chắc_chắn . Gói hàng cẩn_thận chu_đáo',
#  'Thời_gian giao hàng rất nhanh có 2 áo trùng kiểu',
#  'Sản_phẩm mẫu_mã đẹp . Chất_lượng sản_phẩm thì chưa đánh_giá được vì chưa trải qua sử_dụng . Shop phục_vụ rất tốt , rất nhiệt_tình . Thời_gian giao hàng cũng khá nhanh 3 ngày đã nhận hàng . Đã check : không biết có phải chính hãng hay không AE xem hình mình update kèm hihi . Thanks shop lần sau ủng_hộ nữa',
#  'Chất_lượng sản_phẩm tuyệt_vời đẹp dùng ổn',
#  'Rất đáng tiền\xa0 Thời_gian giao hàng rất nhanh Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt',
#  'Hàng đẹp tuyệt_vời như hình . Mình ở xa mua cũng sợ nhưng shop gửi hàng đẹp không lỗi giày ko nhăn_nheo . Rất hài_lòng . Sẽ ủng_hộ shop dài_dài ạ 😘',
#  '" 17 cu thì mua lg v10 vừa đẹp mà con dư tiền "',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Rất đáng tiền Thời_gian giao hàng rất nhanh . Giày đẹp y hình shop đăng .',
#  'Size 3xl mà 62kg mặc vừa shop gọi điện_thoại tư_vấn nhiệt_tình và chu_đáo nhưng sản_phẩm ko giống như mô_tả sản_phẩm vải đẹp nhưng đường chỉ may vắt_sổ còn thừa quá nhiều chỉ',
#  'Không hài_lòng đã nhắn shop là gửi đồng_hồ mặt nhỏ rồi lại gửi mặt lớn to đeo ko đẹp mà mua 3 cái rồi đó',
#  'Chuẩn hàng lắm mn ạhh ! ! ! lên tone nhiều & ko hề lộ vân gì cả nên đố ai biếttt 😍 Ko dính quần_áo mình xịt lên quần_áo đen cũg k dính\xa0',
#  'Shop gói hàng xinh_xắn cẩn_thận . Đàn nhỏ xinh và âm nghe cũng hay . Mình rất hài_lòng',
#  'Bộ khung khó sài lên hình méo_mó không đẹp',
#  'Đèn leb shop gửi câu lộn dây ... gắn vào xe ko sáng đèn ... cần lưu_ý hàn cho đúng cực âm dương',
#  'giống hình quảng_cáo . đáng tiền',
#  'Rất đáng tiền . Đẹp và y_như hình . Shop phục_vụ rất tốt',
#  'Hàng chất_lượng tốt . Giao hàng nhanh_chóng . Shop uy_tín',
#  'hang ko thật như hinh ảnh hàng gui là hàng phek ko đúng hàng như shop nói .',
#  'Dầu rất thơm bỏ vào máy phun sương khuếch_tán thơm cả phòng luôn . cảm_ơn shop đã đem đến một sản_phẩm thiết_thực',
#  'Giao hàng nhanh sản_phẩm đẹp lắm i hình luôn',
#  'Gương hơi mờShop k rep tn Thật_sự thất_vọng Vẽ lem , loãng Ai mua hàng đừng dựa vào lượng feedback mà mua như mình',
#  'xui xui trúng cây ko có miếng lót ko xài đc',
#  'mình nhập Đúng tên và mật_khẩu nhưng không vào được',
#  'Chất_lượng sản_phẩm tuyệt_vời \xa0 Đóng_gói sản_phẩm rất đẹp và chắc_chắn \xa0Đóng gói sản_phẩm rất đẹp và chắc_chắn',
#  'xấu wa',
#  'Chưa xai chưa biet sao\xa0',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn Thời_gian giao hàng rất nhanh . Chất vải hơi mỏng dày thêm tí nữa thì đẹp',
#  'Led sáng ngon . Chất_lượng sản_phẩm tuyệt_vời',
#  'Nói là tích điện nhưng sạc điện không vô ...... theo mình các bạn không nên mua sản_phẩm này mua về tốn tiền mà không sử_dụng đượcBán hàng không có tâm .... Chất_lượng sản_phẩm rất kém',
#  'Mua phi ca tien . cau qua kem',
#  'Đóg gói ko đep',
#  'giao hag z mà cug lộn sai nửa ... dat sai 31 ma giao sai 28 ak',
#  'Ngon giòn đáng tiền nhưng tiền ship hơi cao : ) )',
#  'Hàng rất tốt , giao hàng rất nhanh , và gói hàng rất cẩn thận Cảm ơn shop vì cái giắc DC',
#  'Chất_lượng sản_phẩm rất kém mùi nhựa rất hôi độc_hại nên không dám cho con ngồi . Giờ vứt \xa0xó . Mua phí tiền . \xa0',
#  '" đang định lên con aiphone 7 mà nghe quảng_cáo thiếu nhiều thứ quá chắc không mua , tưởng dùng camera kép , tưởng dùng dual pixel , tưởng dùng flash kép , tưởng bỏ home vậy lý , tưởng nhiều thứ nữa , vậy_mà giá trên trời , hjc hjc "',
#  'giày phù_hợp giá tiền',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn ! Rất đáng tiền !',
#  'Mói dùng mây hôm rât tôt về lâu_dài thi chờ xem . Trước_mắt hàng chất_lượng giá rẻ .',
#  'Đẹp mà đường_nét tinh_tế lắm',
#  'Mọi người nên mua lạp_xưởng tươi của shop Đi nha rất là ngonvà ko bị ngán nữa trên cả sự mong_đợi của mình . Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Rất đáng tiền Thời_gian giao hàng rất nhanh',
#  'Rất đáng tiền Chất_lượng sản_phẩm tuyệt_vời . thank shop',
#  'Sản_phẩm oke\xa0',
#  'Giày làm = chất_liệu gì mà hôi quá !',
#  '" Tôi xài M7 từ lúc mới ra tới giờ , ko có lý_do gì để đổi máy khác , phần_cứng và phần_mềm rất tuyệt_vời . Tôi vô_tình làm rớt từ độ cao hơn 1 m ko dưới 10 lần mà giờ sử_dụng vẫn ok ngoài cái võ_bị xước "',
#  'Sản_phẩm đẹp . Đóng_gói chắc_chắn . Nhưng k có pin dự_phòng .',
#  'kém chất lượngmua phí tiền',
#  'Đẹp lắm shop ơi',
#  'đúng sản_phẩm lắp tháo dễ_dàng giao nhanh',
#  'Đã bỏ thích theo dõi fanpage của tiki gỡ app tiki vì lúc nào phải thấy bản mặt lờ của chi pu',
#  'Chất_lượng sản_phẩm tuyệt_vời . Đồng_hồ cứ bị đẹp quá . Rồi lại phải mua thêm 2 cái nữa . 😍😍😍',
#  'Chất_lượng sản_phẩm tuyệt_vời . Mỗi_tội đơn_vị vận_chuyển chậm quá . 5 ngày mới nhận đc ~ . ~',
#  'Giấy quá mỏng đọc khá là đau_đầu . Tên_riêng dịch ra tiếng việt đọc hơi ... : ( Mình thấy mọi người khen nhiều nên mới mua thế_mà ... thất_vọng quá : (',
#  'Khá là ƯNG Với giá này mua được đôi ntn là quá tuyệt rồi',
#  'Nội_dung mình không bàn nữa vì sách mình mua tặng bạn thôi chứ cũng chưa đọc bao_giờ nhưng mjk bực kinh_khủng vì sách quá bẩn luôn > < chưa bao_giờ mình bực tiki như_vậy luôn ấy .... mong là không gặp đợt hàng nào như_vậy nữa ...',
#  'Rất đáng tiền cảm_ơn sop nhiều nha hang ok lắm hàng dùng đc e sẽ ủng_hộ sop lau dài',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn Số đúng chỉ để vào mạng .. chứ không dùng để nghe gọi',
#  'bạn cùng phòng mua shoppe có 260k . mình mua 440k . mà chất_liệu k bằng . mới móc có mấy bộ áo_dài đã gãy . tưởng tiki bán hàng uy_tín nên chấp_nhận mua giá cao hơn . nhưng quá thất_vọng . k bao_giờ mua và giới_thiệu tiki nữa',
chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Thời_gian giao hàng rất nhanh Rất đáng tiền Shop phục_vụ rất tốt',
#  'Vở rất đẹp',
#  'Khác so với hình_mẫu',
#  'Chất_lượng sản_phẩm tuyệt_vời . Ốp rất là ưng_ý 😘😘',
#  'Chất_lượng tốt đóng_gói đẹp nếu giảm độ mặn chút_xíu sẽ ăn được nhiều hơn .',
#  'Quat be giu trả rát mat thoi gian kg co thoi gian Rất không đáng tiền',
#  'Sim mất 1 tháng sai_lầm khi mua Chất_lượng sản_phẩm rất kém',
#  'sản_phẩm loa bass 20cm nhận mà đã bị hư lỗi không hoạt_động .. buồn vậy !',
#  'Rất yếu . Ko dùng được',
#  'giày tốt mang êm ; cho sao ít vì chọn giao hàng trong ngày mà tận 3 ngày kể từ ngày order mới nhận được',
#  'Shop giao thiếu dụng_cụ lấy mụn cho e mất rồi',
#  'Hag tam dc Hag bi lem keo nhieu wa Mjnh co luu y shop nho kt truoc Ma nhan hag kt thay lem keo rat nhieu Lan sau shop luu y chat luong de kh hag yen tam',
#  'Tôi nhận được 2 hũ 1 hũ còn nguyên tem 1 hũ tem chống hàng giả bị rách sản_phẩm đã bị mở ra trước đó và dán keo lại dấu keo đen nham_nhở trên sản_phẩm . Rất không hài_lòng về cách',
#  'Dập có trợ_lực xài tốt . Tuy giá có hơi cao tí . Sp đúng như mô_tả . Shop nhiệt_tình giao đúng mẫu .',
#  'Chất_lượng sản_phẩm tuyệt_vời sẽ ủng_hộ ..',
#  'Giao sai hàng cho khách',
#  'Sp tạm dùng được',
#  'Sản_phẩm cực kém chất_lượng . Cường_lực để xước hết . Dán vào nhìn cái máy không khác gì đồ bỏ .',
#  'Giày đẹp vải tốt rất đáng tiền 💚',
#  'Chất_lượng sản_phẩm rất kém Rất không đáng tiền . Dùng bị nên nốt đỏ tốt nhất không nên mua',
#  'Ghế chắc_chắn',
#  'Ưng_ý ❤ sẽ ủng_hộ nhiều đơn hàng nữa ạ Đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn . Mình chưa dùng nên chưa rõ chất_lượng nhưng hy_vọng sẽ tốt . Thanks shop',
#  'ừ thì là mà quá tuyệt_vời .... Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Rất đáng tiền',
#  'Đồ đẹp nhưng shop gửi hàng chậm quá hichic dù_sao vẫn cho shop 5 sao . Lần sau shop nên gói hàng ki hơn tý nữa ạ',
#  'Chất_lượng sản_phẩm ok . 💕',
#  '\xa0Đóng gói sản_phẩm rất đẹp và chắc_chắn gjầy mang rất êm giao hàng rất nhanh',
#  'Hài_lòng . thời_gian giao hành nhanh .',
#  'Chất\xa0 Chất_lượng sản_phẩm tuyệt_vời . Đc shop tặng thêm gói trà đào xinh_xinh 😘 . Sẽ ủng_hộ shop nhiều hơn\xa0',
#  'Hàng đẹp : ) ) Siêu xinh xắn\xa0',
#  'Chất_lượng sản_phẩm rất kém đồng_hồ hết pinshop phục_vụ kémib k trả lời.mn nên cân_nhắc trc kbi mua',
#  'Đẹp xuất_sắc nè',
#  'Chất_lượng sản_phẩm tuyệtvời nhung con hoi dau',
#  'Mùi thơm dễ_chịu Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắ
#  'Chất_lượng sản_phẩm tuyệt_vời Chất_lượng sản_phẩm tuyệt_vời Shop phục_vụ rất tốt Rất đáng tiền Thời_gian giao hàng rất nhanh . Đóng_gói k kỹ cho lắm',
#  'đặt trưa hqua trưa hnay có hàng làm_ăn rất mau_lẹ 5 sao',
#  'Dùng được mấy ngày mà nút chuột giữa đã không cuộn lên cuộn xuống được shop mất uy_tín quá',
#  'Rate 5 sao giao hàng nhanh + hàng đúng với mô_tả .',
#  'Shop ơi chán quá hôm_nay hí_hửng rất thích đồng_hồ này nhưng e chưa dùng hết cả ngày\xa0Chỉ rửa tay vói tắm thôi\xa0 Đồng_hồ đã hấp_hơi hết ở trong rồi 😭😭',
#  'Lúc tôi đặt hàng là 109k tại sao đến lúc giao lại lấy 125k . Phải lấy đúng giá so với lúc đặt hàng chứ . Chất lượng sp khá đc vừa tầm tiền',
#  'Sản_phẩm phải bảo_quản ở nhiệt_độ 0-5 độ C mà gói hàng Shop gởi hôm_qua GHN chiều hôm nay mới giao hàng trong điều_kiện bình thường.Mình có hỏi Giao hàng nhanh thì ngta nói k nhận giao hàng bảo_quản lạnh nên mình nghĩ Shop nên tự giao hàng sẽ tốt hơn cho khách_hàng',
#  'mở gói ra đã thấy vết cắt ... 👎 chất_lượng thì ...',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn Chất_lượng hàng phù_hợp với giá tiền',
#  'Giao ko dung hàng bao bi cũ nát . Thay doi sp ko báo trước cho khách biet',
#  'dây xài quá dở ko có độ đàn_hồi . phí tiền mua bực vào người .',
#  'Đóng_gói cẩn_thận chất_lượng ok',
#  'Size không đúng chuẩn không đúng như quảng_cáo .',
#  'Đầu cắm micro usb gia_công quá tệ . Không cắm vô được Galaxy A3 2016 .',
#  'Bắp_tay bắp_chân dùng có tác_dụng nhanh tiếc mỗi bụng mình rạn k dùng dc vì quá ngứa 🙄 Nói_chung ok\xa0 Chất_lượng sản_phẩm tuyệt_vời',
#  'Mình hâm_mộ anh Minh_Nhật từ lúc đọc những tác_phẩm của anh ấy trên Trà sữa cho tâm_hồn khi ấy văn_phong của anh đầy tính nhân_văn và cảm_xúc . Nhưng khi mua quyển Nơi những cơn gió dừng chân này thì mình vô củng thất_vọng . Cốt_truyện lộn_xộn truyện này liên_kết truyện kia bằng cách thay_đổi nhân_vật khiến truyện phức tâp rối_bù cả lên . Nội_dung cũng không thực_sự đặc_sắc đa_số chỉ xoay quanh công_việc và chuyện tình tan_vỡ của nhân_vật . Điểm cộng duy_nhất của tác là bìa được thiết_kế đơn_giản và rất trang_nhã với tông màu hồng .',
#  'Đóng_gói tốt , hàng đẹp và chất_lượng',
#  'Chất_lượng sản_phẩm rất kém .. quá yếu chỉ sôi ụt ụt .. trứng còn ko chín .. quá sai_lầm',
#  'Hàng giao không đúng như hình_ảnh nhãn_mác đè lên nhau',
#  'Hàg tốt . Giá tốt 👌🏻',
#  'Bánh_dẻo ngon vô_cùng ! ! Giá_cả rẻ so với chát lượng mn nên ăn thử nhé ! ! ! Sẽ ủng_hộ ! \xa0 Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn

#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn Thời_gian giao hàng rất nhanh . Ốp khá đẹp nhưng màu hơi tối so với ảnh trên mạng .',
#  'E đặt tưởng màu đen Ai dè ra màu này : v Y_chang con_nít 👶',
#  'Mình rất hài_lòng với thời_gian giao hàng rất nhanh chuột cầm rất đã tay đầm và chắc_tay nhưng đồng_thời vì chuột đầm nên hơi nặng . Do chuột còn mới nên cái nút ở chỗ ngón tay cái và nút giữa chuột khá cứng hơi khó nhấn . Kết_nối với thiết_bị tuyệt_vời với 3 thiết_bị cùng lúc . Rất đáng tiền mua',
#  'áo nhìn khác hẳn với hìnhthô quá và vải hay xù',
#  'Shop phục_vụ tốt sản_phẩm tốt',
#  'Thấy có đủ dung_lượng sim đã đc kích_hoạt trước nên k bit dc đến bao_giờ sóng cũng tạm đc .',
#  'Chất_lượng sản_phẩm tuyệt_vời . Đóng_gói sản_phẩm rất đẹp và chắc_chắn . Shop phục_vụ rất tốt Shop phục_vụ rất tốt . Rất đáng tiền . Thời_gian giao hàng rất nhanh . Ck mình rất thíchnhìn đẹp . Cám on shop nhiều có nhu câu sẽ ủng_hộ tiếp : )',
#  'Hàng dùng ok tốt cho shop 5 * dùng hơi nóng nhưng không sao tốc_độ mạng ổn_định Chất_lượng sản_phẩm tuyệt_vời',
#  'Quá xịn',
#  'Máy rẻ chạy ổn',
#  'Mình nhận được hàng rồi thời_gian giao hàng rất nhanh sản_phẩm rất oke . \xa0',
#  'Tiền nào của đấy . Chất xấu . Hàng gia_công . Chịu',
#  'sử_dụng ko mượt như trc đây',
#  'Mạch rất ổn',
#  'Xin hỏi sao máy của mình bị lỗi hở viền bên công_ty kiểm_tra lâu vậy_mà ko có kết_luận để đổi máy mới cho mình . Ko có máy dùng hỏng mất bao_nhiêu việc',
#  'Chất_lượng sản_phẩm tuyệt vời\xa0 Đóng_gói sản_phẩm rất đẹp và chắc_chắn !',
#  'Hãy để vẻ đẹp của Hà_Nội được thể_hiện qua vẻ đẹp của cả nước !',
#  '" Đặt ra giá này ế là cái chắc "',
#  'Tất quá xầu',
#  'đồng_hồ mất chốt thì quay cái gì điều_chỉnh cái gì ? Chất_lượng sản_phẩm kém',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Thời_gian giao hàng rất nhanh Hàng rất đẹp mềm nhẹ dầy_dẶn rất đẹp . Sẽ ủng_hộ shop dài_dài',
#  'Đồng gói sản_phẩm rất tốt',
#  'hạt bầu ươm 5 ngày chưa thấy nẩy mầm .',
#  'Mặc_dù đã được đóng_gói nhưng khi mở ra thì trông như hàng cũ ấy ạ vỏ ngoài có chỗ bị móp viền vàng bị tróc xung_quanh luôn bên trong thì khô cầm lên thấy nhẹ_tênh lúc chuốt mi thì cảm_giác nặng_trĩu vón cục mình mua hàng trên shopee nhiều rồi nhưng đây là lần đầu mình đánh_giá thấp như vậy : (',
#  'Mình chưa dùng kem trị sẹo nên không review được nè , nhưng Baking_Soda thì ok rồi , mình mua để tẩy_rửa nhà_tắm rất ổn . Gói hàng kỹ_lưỡng , không móp méo , giao hàng đúng ngày quy_định luôn . \xa0 Bạn nên xem_xét thử nhập về thêm mấy đồ_dùng trong gia_đình nhỏ nhỏ xinh_xinh nhé . Có thì mình sẽ ủng_hộ nè',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắ
chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất chắc_chắn .',
#  'Như cái lol',
#  'Mới mua đeo đã chạy sai nhưng liên_hệ shop để bảo_hành nhưng shop ko trả_lời . Giống lừa quá',
#  'Chọn 1 màu giao 1 màu lúc đặt_hàng k nói trướcthất vọng quá toàn màu xấu',
#  'Gói hàng quá ẩu bịch sữa còn bị rách',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn . Mình chưa dùng thử nhưng nhìn cảm_quan cushion rất xinh_son chuẩn băng đô đẹp mềm mịn Đóng_gói sản_phẩm rất đẹp và chắc_chắn Thời_gian giao hàng rất nhanh',
#  'chất_liệu vải cực_kì xấu',
#  'Sp k khô rất nhão và có sạn .',
#  'Quá tệ . đặt_hàng mặt xanh giao hàng mặt trắng',
#  'Giày đẹp như hình đã mua 1 đôi chất_lượng tốt nên mua thêm đôi màu khác rất đáng tiền . \xa0 Thời_gian giao hàng rất nhanh',
#  'Shop lừa_đảo treo đầu dê bán thịt chó địt_mẹ chỉ vì tiền ...',
#  'Phím hỏng k bấm đc chữ đéo nào . Lừa_đảo các bạn đừng lên mua đồ ở cái shop này . Đm nhận đc cái phím chưa kịp cười đã ức vì bị lừa trắng_trợn',
#  'sản_phẩm như con cặc đéo xài được . lừa_đảo',
#  'Chất_lượng sản_phẩm tuyệt_vời Shop hỗ_trợ tốt và tận_tình . Nhưng chưa biết độ bền ra sau .',
#  'Ok . Giầy đẹp như hình . tks',
#  'Tả rất mỏng và hình_ảnh in k sắc nét . Lúc đầu mình đã nghi_ngờ là tả giả do con mình mặc bị dị_ứng nổi đỏ khắp mông ngưng k mặc nữa thì lại hết . Hnay mình cho mặc lại thì đúng y lại nổi đỏ khắp mông . Mình nghi_ngờ về chất_lượng và nguồn_gốc xuất_xứ của tả',
#  'Hũ nhựa có nắp kép ở trong sạch sẽ',
#  'Sản_phẩm tuyệt_vời . Giao hàng nhanh nữa',
#  'Chất_lượng sản_phẩm tuyệt_vờI Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt',
#  'Hàng đúng như trên shop đăng chất_lượng tốt',
#  'Chất_lượng sản_phẩm tệ không có cáp sạc đi kèm khi hỏi shop kiểm_tra lại hàng shop không phản_hồi trong khi đang ol rồi biện_minh là cam quay hàng có cáp sạc bảo cho xem ảnh thì k gửi rồi ăn_nói thô_lỗ những khách_hàng đánh_giá 5 * thì shop nhẹ_nhàng nịnh_nọt ai đánh_giá 1 * thì nói_khó nghe',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Rất đáng tiền Thời_gian giao hàng rất nhanh Lạp thịt Nạt nhiều . Ngon\xa0',
#  'C chủ dthương nhiệt_tình . Mấy phụ_kiện dễ cưng lắm luôn😍',
#  'Vali có vài vết xước nhỏ nhưng ksao vì màu quá đẹp hàng chuẩn mình còn ngồi lên kt độ bền nữa = ) ) rất ok lunn\xa0 Shop phục_vụ rất tốt Rất đáng tiền Thời_gian giao hàng rất nhanh',
#  'Chất_lượng sản_phẩm tuyệt_vời Tuy_nhiên mình đã ghi_chú đongs nguyên hộp mà shop lại ko cho vào hộp nhưng thôi ko sao',
#  'sách nhận bị chập góc nên ko vui lắm bìa mềm và giấy rất mỏng khác xa với mong_muốn lúc mua vì tưởng 185k thì giấy cũng ok xíu mua tiki vài chục quyển r thì có bị vài lần ko vui vì sách nhận bị chập góc quá nhiều r bị rách bìa nữa',
#  '_Son fake . Đánh lên môi k bám .',
#  'nếu bật chế_độ full screen và lướt web đọc báo sẽ thấy khá khó_chịu vì màu_sắc ko đều . bật chế_độ 3 phím ảo ở dưới sẽ thấy đỡ ám vàng vì ko phải đọc nội_dung dưới cùng',
#  '" Xấu hơn S6 active . nhưng nếu về VN mình chọn S7 active vì hình_như em nó hỗ_trợ thẻ nhớ . trước lăn_tăn S6 active nhưng không có thẻ nhớ nên thôi : ) ) "',
#  'Hà_Nội ơi , để kỷ_niệm đại_lễ 1000 năm Thăng_Long - Hà_Nội , xin hãy làm một việc có ý_nghĩa , hãy dành chút tiền để sửa_sang vỉa_hè xung_quanh hồ Hoàn_Kiếm với dự_án là 40 tỷ đồng đó để xây_dựng giúp Đắc_Ang một , hai cây cầu đi nhé .',
#  'Rất đáng tiền \xa0ok',
#  'Giao hàng nhanh đủ goi bọc hàng tạm tạm . chưa biết dán thế_nào nhưng thấy cũng Ok . Mong miềng dàn sẽ như kì_vọng ko bị bong ra . Sẽ tiếp_tục mua của shop trong tương_lai',
#  'Không thấy giao chung đoen hàng . Bị thiếu .',
#  'Nhỏ hơn màn_hình j7 prime rất nhiều',
#  'đi êm chân lắm nhé shop ơi',
#  'kém . hỏi cái gì cũng bảo không biết nhận hàng lỗi báo thì không thèm trả_lời QUÁ KÉM CẢ CHẤT_LƯỢNG VÀ TƯ_VẤN',
#  'Kem mịn tệp màu . Nghĩ 52 sáng nhưng hoá_ra vừa in luôn rất nhẹ mặt tự_nhiên',
#  'Chất_lượng sản_phẩm rất đẹptuy bé mặc hơi rộng chút',
#  'Khi tôi nạp thẻ thì bị báo đã sử_dụng rồi . Nhưng khi shopee giải_quyết thì vẫn trả tiền cho shop . Có_lẽ biết chắc vẫn đc thanh_toán nên shop thật vô_trách_nhiệm khi người mua liên_lạc báo là ko nạp được . Bán hàng ko có tâm . Các bạn nên cân_nhắc trước khi mua . Tôi đã mất 90k tiền ngu .',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Chất_lượng sản_phẩm tuyệt vời\xa0 Thời_gian giao hàng rất nhanh Rất đáng tiền',
#  'Do đơn_vị giao hàng hay do shop ? ko kiểm hàng bị ntn !',
#  'Như mong_đợi . Sẽ ủng_hộ shop dài_dài',
#  'hàng đẹp sẽ còn ủng_hộ nữa . chúc shop buôn may bán đắt',
#  'Shop phục_vụ rất tốt . màu_sắc đẹp chất hoi nhiều nilong nhưng so với giá là quá rẻ',
#  'Rất không đáng tiền Thời_gian giao hàng rất chậm Shop phục_vụ rất kém',
#  'Đỏ gạch cam đất_đỏ đất . ( màu đỏ đất đẹp hết_sảy con bà bảy ) ưng lắm nhưng màu đỏ gạch thì ít đỏ quá : ( ( ( ( ( (',
#  'Chất_lượng sản_phẩm tuyệt_vời Thời_gian giao hàng chậm . 5 diem sao',
#  'Sp y hình Đóng_gói sản_phẩm rất đẹp và chắc_chắn Thời_gian giao hàng rất nhanh',
#  'mình chưa dùng nhưng thấy lọ chiết rất xinh nếu dùng hợp sẽ ủng_hộ tiếp',
#  'Mẫu ko giống trong hình',
#  'Re ma dep',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Thời_gian giao hàng rất nhanh . Rất vừa_vặn . Shop làm_ăn rất tốt',
#  'ừ gửi đúng hàng.mà ko có dây phone.uổn quá.máy màu đen xì toàn_bộ như than chứ ko phải như hình_mẫu trắng_đen đâu .',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt',
#  'Chất_lượng sản_phẩm tuyệt_vời Rất đáng tiền Thời_gian giao hàng rất nhanh . Sản_phẩm tặng rất đẹp nhe moi nguoi',
#  'Quạt chạy êm . Khoẻ . K biết lâu_dài thì có bền ko . \xa0Shop phục_vụ tốt',
#  'Thời gián giao hàng quá lâu . Ko chủ_động thông_báo cho KH',
#  'Mình đã báo lấy cho con trai thì lấy màu ghi xám thôi shop cho cả màu hồng mầu cảm . Quá dở',
#  'đặt màu vàng giao màu trắng ok vì shop vẫn gọi điện cho khách trước nhưng hoàn_toàn thất_vọng k giống hình 1 tí nào',
#  'Chất_lượng sản_phẩm rất kém bị sước nhiều chỗ . Đóng_gói sản_phẩm rất kém xe bị gãy . Và thiếu một số phần . Shop phục_vụ rất kém . Rất không đáng tiền .',
#  'Mình đã mua của shop khoảng 45 lần rồi . Lần đầu cho shop 2 sao . Với lý_do đóng_gói quá sơ_sài khi nhận hàng khui ra có một chai đã chảy gần một_nửa . Mong shop lần sau chú_ý cách đóng_gói sản_phẩm . Đóng_gói tốt cũng là một_cách trân_trọng khách_hàng của mình .',
#  'Vải dc nhưng giao hàng lộn_xộn lại thiếu hàng',
#  'Áo vay ma bao_la giong ( may chu mickey đen con in loang lố ) noi chung k hai_Long . Keu tra hang thi con lâu cho tra nhe',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn . Rẻ mà chất_lượng',
#  'Shop phục_vụ rất tốt nhiệt_tình . Sẽ ủng_hộ dài_dài ^ v ^',
#  'Giày nhẹ mang êm chân',
#  'Giày dễ thương lắm êm thoải mái nè',
#  'Sp trục_trặc . Xin tư_vấn of shop thì shop hok trả_lời . Phục_vụ kém',
#  'Giày rất đẹp mềm dễ đi . Đóng_gói cẩn_thận',
#  'Ok đấy . Thời_gian giao hàng rất nhanh',
#  'Cái này là Gel_MH không phải là Decumar .',
#  'Chất_lượng sản_phẩm rất kém giao sp hu KH bao lai lo nhu ko bit ban uy tin chi co 175k . Qua toi . \xa0 Shop phục_vụ rất kém',
#  'Hàng đẹp nhưng dây giày hơi bẩn\xa0',
#  'vải quá xấu . mặc ngứa',
#  'Hết hàng nhưng không báo trc cho khách . Hơn 1 tuần sau shipper đến giao mới bảo r hoàn lại tiền',

#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Ưng lắm luôn nhưg chụp hình lúc đi lm ko bắt_mắt lắm 💋💋',
#  'Chất_lượng sản_phẩm rất kém pin không đúng như quảng_cáo hình_ảnh và sẽ không có lần thứ 2 mua của shope nữa',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Thời_gian giao hàng rất nhanh Gói cái vỏ Ko bóp đc là buồn r',
#  'hàng kém chất_lượng . BÁN HÀNG CHÁN',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn . dag gia tiền',
#  'mới hút bụi chưa được 2 phút hư luôn ..',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn . Chưa sử_dụng nên chưa báo được chất_lượng !',
#  '" chẳng khác gì iphone 6 "',
#  'Lan đau mua cua shop . Giao hang nhanh nhu 1con gio . Gia ca canh tranh . \xa0San pham chat luong . Ngọt . Cay . Sach se đựng trong họp chac chan . Cho them 5 * la 10 * luon . Chuc shop co that nhieu khách hang',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Rất đáng tiền Rất đáng tiền Thời_gian giao hàng rất nhanh . Còn tặng thêm 1 gói dưỡng trắng nữa . Tks shop\xa0',
#  'Hàng rất đẹp . Form giày chuẩn . Mình rất hàng lòng đóng_gói đẹp . Mình đã mua thêm đôi nữa',
#  'loa khi nói_chuyện quá nhỏ người nghe không nghe rõ gì hết .',
#  'Đặt màu đen thì vỏ hộp xanh ruột lại trắng.quá thất vọng.trả hàng thì phức_tạp nt shop ko bgjo trả lời.cạch',
#  'Chất_lượng sản_phẩm rất kém1 bên loa bị hỏng',
#  'Mạch sạc ko ổn_định',
#  'Không tốt',
#  'Đóng_gói sản_phẩm tốt giao hàng nhanhphù hợp với giá_thành',
#  'tại_sao khi nhận hàng trên hộp ghi là xuất_xứ Trung_Quốc',
#  'Rất đáng tiền Shop phục_vụ rất tốt Thời_gian giao hàng rất nhanh',
#  'C chủ và nhân_viên dễ_thương vui_vẻ sẽ ủng_hộ dài_dài',
#  'Chất_lượng sản_phẩm tuyệt_vời Shop phục_vụ rất tốt Rất đáng tiền Hàng chất_lượng tốt lại lung_linh nữa 😘',
#  'Trong ảnh đẹp mà ngoài nhìn xấu kém',
#  'Đẹp và thích lắm',
#  'Giày bẩnbảo đổi hàng shop k đổi',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn . Mới dùng thử thì khá ổn . Sẽ tiếp_tục ủng_hộ shop .',
#  'Màu sơn dưới đế giầy mờ và tróc nhiều ko hài_lòng cho lắm',
#  'Xay chưa xong 1 lần cá lần rùi không sử_dụng được nữa',
#  'Sản_phẩm rất đẹp chất_lượng thì khỏi chê luôn . Giao hàng nhanh . Cảm_ơn shop',
#  'Hang k nhu hình hang k ro nguồn goc Chất_lượng sản_phẩm rất kém',
#  'Bánh to tròn múp_míp : 3 Ăn đã lắm hehe : 3 Được tặng kèm gói bánh này đâyyy : 3 Gói bánh tặng ăn vui mồm mỗi_tội hơi cứng',
#  'Shop không tốt',
#  'Chất_lượng sản_phẩm tuyệt vời\xa0 Thời_gian giao hàng chậm',
#  'Giày khá đẹp . Như real luôn : ) ) ) ) thanks shop',
#  '\xa0Giầy đẹp ngon bổ lại rẻ nhé',
#  'Dùng cá_nhân 100ea nhiều quá',
#  'Hi shop giao màu ngẫu_nhiên mà đẹp chất cũng mềm mịn ưng lắm\xa0',
#  'Hơi thất_vọng khi nhận được sp',
#  'Đặt xương_rồng mà_lại gửi cờ nhật ah',
#  '1 . Nhận_diện bằng mắt thường . hộp ọp_ẹp không có tem hãng không có giấy hướng_dẫn sử_dụng . ghi gờ hàng giả KÉM chất_lượng . đề_nghị kiểm_tra chất_lượng sản_phẩm',
#  'Mặt hơi to Chất_lượng sản_phẩm kém',
#  '- keo tốt - kiểu ống chích này tra keo vào CPU tiện hơn loại hủ',
#  'Hàng tốt cám_ơn shop nhờ có cái này mà con mình uống nước dễ_dàng hơn',
#  'Chúng_ta có không ít giải_pháp để đảm_bảo an_toàn mà vẫn giữ nguyên vẻ thơ_mộng của Cầu Long_Biên .',
#  'Máy có đèn led đổi màu xanh_đỏ cho vui chứ ko có tính_năng hồng_ngoại . Dùng massa gáy , đầu thấy ko ổn lắm , nằm lên lúc máy hoạt_động khá khó_chịu . Chạy mấy phút thì động_cơ khá nóng . Ngại đổi trả nên dùng tạm để massa chân . Khuyên các bạn ko nên mua .',
#  'Ưng cái bụng😊😊😊',
#  'xài khá ok',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn mua 2 lần rồi lần nào cũng ok lăm luôn',
#  'Bàn_phím cắm vào không có nhận gì cả . Shop ko có kiểm_tra hàng trước khi giao . Liên_hệ ko thấy trả_lời . Nản .. Rất không đáng tiền',
#  'Làm_ăn không uy_tín mua 2 thì giao 1 . Gọi điện báo lại.thì nhân_viên phục_vụ thái độ.Cuối năm rồi nên không thèm kiện_cáo nữachấp nhận trả_giá gấp đôi nhưng shop.xem lại cách làm_việc của mình đi.Tiền dù ít cũng là tiềnbuôn bán có tâm chút nhé shop .',
#  'Shop phục_vụ rất tốt , đóng_gói chắc_chắn Bột đậu thơm Còn hiệu_quả thì để sd 1 thời_gian nữa mới rw đc nha .',
#  'Tuyệt_cú mèo',
#  'Hàng đẹp vải thun ok Không được chọn size nên hơi rộng nhưng k sao phù_hợp với túi_tiền Khuyên bạn nào cao trên 1m75 thì mặc ok nhé',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn Đóng_gói sản_phẩm rất đẹp và chắc_chắn Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Đóng_gói sản_phẩm rất đẹp và chắc_chắn Chất_lượng sản_phẩm tuyệt_vời',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Rất đáng tiền',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn Thời_gian giao hàng rất nhanh nhung hàng hoi bị mop cần nhe Tay hơn khi van chuyển',
#  'Đồng_hồ đẹp lắm shop . Chỉ có_điều khoá đóng mở dít chặt quá cậy mạnh mới ra nên hơi bất_tiện .',
#  'Nhanh . Đẹp . Nhưng có thấy ghi_chú là . GÓI MASSAGE + CẠC MOBI 20K . mà gói có . Cạc thì ko .',
#  'Giao hàng thiếu khẩu_trang của mình',
#  'Chất_lượng sản_phẩm rất kém Mua hàng trên Shopee nhiều nhưng chưa lần nào thấy thất_vọng như lần này\xa0Bỉm giống như bỉm giả Bóc ra rồi nếu k thì yêu_cầu trả hàng ngay Giờ mua bỉm khác bỉm này dùng hư da con',
#  'Bánh thơm ngon ít ngọt rất hợp_khẩu vị',
#  'Thời_gian giao hàng rất chậm . Lúc mua hàng thì ghi 2-4 ngày nhận mà mãi ngày thứ 8 mới nhận được . Sẽ nói không với GHTK .',
#  'Shop phục_vụ rất tốt - - Chất_lượng sản_phẩm tuyệt_vời',
#  'Đóng_gói giao hàng k ktra.nhầm size.giao hàng k nhanh như các shop khác !',
#  'Shop phục_vụ rất tốt Rất đáng tiềngiao hàng rất nhanh',
#  'Vừa nhận bỉm bóc xem thử rất thick . Bỉm mềm ko khác j moony mà_lại rẻ hơn nhiều . Ahihi',
#  'Nhanh + uy_tín',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn máy chính hãng nguyên hộp',
#  'Thời_gian giao hàng rất chậm',
#  'Shop phục_vụ rất kém Chất_lượng sản_phẩm rất kém',
#  'Chất_lượng sản_phẩm rất kém .. \xa0',
#  'Chất_lượng sản_phẩm tuyệt_vời Chất_lượng sản_phẩm tuyệt_vời . Shop tận_tình thân_thiện .',
#  'cay quá',
#  'Chất_lượng sản_phẩm tuyệt vời.HUHU DO MÌNH MUA HÀNG NHIỀU QUÁ MÌNH NHẦM LẦN SHOP NÀY SHOP KIA.THÔNG CẢM NHÉ.SP RẤT OK VÀ MÌNH SẼ TIẾP_TỤC ỦNG_HỘ > 3',
#  'Hợp đựng đồng_hồ không giống như clip . Sao nó lại ra ten v shop ? ? ?',
#  'Khi cắm vào sạc cho đt không hỗ_trợ sạc nhanh ( đt mình là SS S6 E ) và phải cắm sạc 5 tiếng ms đầy . \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ Đóng_gói sp thì cẩu_thả , bao_bì cũ_kĩ , trầy sước ( dơ ) sau 1 tuần ko còn dùng nó nữa đã vứt xó',
#  'Rất không đáng tiền . Mua 3 cục nguồn về không dùng được cái nào . Hàng kém chất_lượng . \xa0Đồ đểu không dùng được . Không đáng sao nào cả Lừa_đảo',
#  'Hơi rộng nhưng sáng đẹp 😘😘',
#  'Sổ rất đẹp , chắc_chắn , cỡ giấy a5 thôi nhưng sổ to bự luôn . Bút nhũ và sticker cũng rất đẹp . Có mặt_hàng hết nhưng đã đc đền_bù lại đầy đù . Chỉ có là thời_gian chờ hàng từ ngoài về lâu ơi_là lâu , nhưng order là thế nên cx k trách shop đc : v Có tiền nhất_định sẽ mua tiếp vs shop',
#  'Dầu óc chó như cũ_rích k biết có phải hàng chuẩn k nữa',
#  'Lên màu đẹp thơm đóng gói cẩn thận thời_gian giao hàng rất nhanh . Nói chung tuyệt vời < 3',
#  'Chưa dùng nên chưa biết',
#  'Bán hàng cà chớn hì đặt size 39 gửi về 38 mà nt cho shop đổi size thì k ai trả_lời buôn_bán có tâm chút chứ mua hàng k đúng size sao mang hả',
#  'Hàng của shop giao ko hề có banner của Twice',
#  'Tôi thấy cái nào cũng có cái ko tốt , như tôi đang dùng iphone , chỉ đc mỗi cái sành_điệu , còn pin thì yếu , wifi thì kém , nghe nhạc thì chán',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắ

#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Thời_gian giao hàng rất nhanh . Mua shop mấy lần rồi . Lần nào cũng rất ưng_ý ❤️',
#  'Sản_phẩm rất đáng tiền . Đóng_gói sản_phẩm rất đẹp và chắc_chắn',
#  'Màu lên k chuẩn như hình thơm bền màu',
#  'Sản_phẩm bị lỗi - cắm jack 3.5 mm từ dtdd hoặc laptop máy_tính thì ko xài được - Đã test các jack này với cái khác y_chang thì được',
#  'Shop giao thiếu hàng ib hỏi k trả_lời vô_trách_nhiệm .',
#  'Áo đẹp nhg fom hơi bé',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn chưa sử_dụng chưa biết chất_lượng ra sao .',
#  'Bị hết hạng sử_dụng : ) )',
#  'Moi thu lan dau thi thay ok...con k bit su dug lau dai the nao ...',
#  'chất_liệu nó k giống hình ạ.keo dán không đc kết chặt ạ.dinh keo bã nữa a.noi chug thì cung không phải tệ.nhưng e muốn mình mua thời_gian lâu_dài thì hình thật hàng thật.vi e còn mua rất nhiều mặt_hàng ở tại đây mà',
#  'sãn phẫm xấu \xa0 hàng kg tốt treo \xa0đẩu dê bán thịt chó',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt . Góibhangf cực_kỳ cẩn_thận chắc chắc mình sẽ mua tiếp Shop phục_vụ rất tốt Thời_gian giao hàng rất nhanh',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt .',
#  'Sp tốt bọc cẩn_thận',
#  'Phải_chi biết đến shop sớm hơn . 😂 Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất đẹp và chắc_chắn Shop phục_vụ rất tốt Rất đáng tiền Thời_gian giao hàng rất nhanh',
#  'Mặt_nạ tốt . Lần đầu_tiên mua hàng đã tặng sample lại còn hẳn 3 sample mặc_dù chưa có thời_gian nghiên_cứu mấy cái sample đó là gì : ) ) ) ) ) )',
#  'Giao hàng thiếu . Gian_lận combo 10 cái.giao còn 7 cái.ko uy tin.không đáng mua tiếp.chất lượng thì ok',
#  'Sản_phẩm lỗi nhiều',
#  'Vua moi nhan hang đa bị hư dây .',
#  'Bút nhẹ . Viết trơn',
#  'Chất_lượng sản_phẩm tuyệt_vời m mua với giá sale 215k',
#  'vừa nhận hàng . có xay thử thấy cũng được . hợp giá tiền . chỉ ko biết độ bền được bao_lâu thui : ) )',
#  'Đóng_gói sản_phẩm rất đẹp và chắc_chắn nhân_viên giao nhiệt tìn còn về chất_lượng thì đương_nhiên tốt',
#  'Rất lag và khó xem dù sử_dụng iPhone 6S',
#  'Cảm_nhận sau khi mua con điều_hoà này . - Làm lạnh thì chậm m bật 5t từ 10h sáng đến 3h chiều mà phòng chỉ thấy hơi mát mát ( nhiệt_độ ngoài_trời tầm 25 = > 30 độ , phòng m 15 m2 ) - Gọi nv xuống kiểm_tra thì bảo ko bị sao cả máy hoạt_động vẫn bình_thường , mình có bảo làm mát chậm thì lấy lí_do phòng này hướng tây bị nắng hắt vào lên làm lạnh chậm ... - Yêu_cầu trả lại , đổi sang cái khác thì không đổi đc nữa . = > Khả_năng lần sau sẽ xem_xét mua hàng trực_tiếp , ko mua online nữa ... Hết !',
#  'Hơi nhỏ so vs hìh',
#  'Chất_lượng sản_phẩm tuyệt_vời Đóng_gói sản_phẩm rất tệ và Hộp_Hư_Hoàn_Toàn Shop phục_vụ rất tốt Thời_gian giao hàng rất nhanh Nhưng Giày vừa Khuyên các bạn chọn lớn hơn 1size',
#  'Đặt bioderma thì ship sp khác.Hàng k chuẩn.sẽ không có lần sau đặt ở shop nữa : ( (',
#  'tra hàng',
#  'Giao hàng thiếu ib ko trả lời',
#  '" Một thiết_kế không_thể xấu hơn , chào_mừng Apple ra nhập với đội HTC , cổ_phiếu của Apple sẽ sụt như chong_chóng tụt sau khi Iphone 7 và IP7 Plus ra_mắt cho mà xem ! "',
#  'Tốt nen mua',
#  ...]

# %%
from sklearn.model_selection import train_test_split

train_sents, val_sents, train_labels, val_labels = train_test_split(train_text, train_labels, test_size=0.1)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
MAX_LEN = 125

train_ids = []
for sent in train_sents:
    subwords = '<s> ' + bpe.encode(sent) + ' </s>'
    encoded_sent = vocab.encode_line(subwords, append_eos=True, add_if_not_exist=False).long().tolist()
    train_ids.append(encoded_sent)

val_ids = []
for sent in val_sents:
    subwords = '<s> ' + bpe.encode(sent) + ' </s>'
    encoded_sent = vocab.encode_line(subwords, append_eos=True, add_if_not_exist=False).long().tolist()
    val_ids.append(encoded_sent)
    
train_ids = pad_sequences(train_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")
val_ids = pad_sequences(val_ids, maxlen=MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

# %%
train_masks = []
for sent in train_ids:
    mask = [int(token_id > 0) for token_id in sent]
    train_masks.append(mask)

val_masks = []
for sent in val_ids:
    mask = [int(token_id > 0) for token_id in sent]

    val_masks.append(mask)

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
import torch
train_inputs = torch.tensor(train_ids)
val_inputs = torch.tensor(val_ids)
train_labels = torch.tensor(train_labels)
val_labels = torch.tensor(val_labels)
train_masks = torch.tensor(train_masks)
val_masks = torch.tensor(val_masks)

train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = SequentialSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=32)

val_data = TensorDataset(val_inputs, val_masks, val_labels)
val_sampler = SequentialSampler(val_data)
val_dataloader = DataLoader(val_data, sampler=val_sampler, batch_size=32)

# %%
from transformers import RobertaForSequenceClassification, RobertaConfig, AdamW

config = RobertaConfig.from_pretrained(
    "/content/drive/My Drive/BERT/SA/PhoBERT_base_transformers/config.json", from_tf=False, num_labels = 2, output_hidden_states=False,
)
BERT_SA = RobertaForSequenceClassification.from_pretrained(
    "/content/drive/My Drive/BERT/SA/PhoBERT_base_transformers/model.bin",
    config=config
)
# Out:
# Some weights of the model checkpoint at /content/drive/My Drive/BERT/SA/PhoBERT_base_transformers/model.bin were not used when initializing RobertaForSequenceClassification: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at /content/drive/My Drive/BERT/SA/PhoBERT_base_transformers/model.bin and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
BERT_SA.cuda()
print('Done')
# Out:
# Done

# %%
import numpy as np
from sklearn.metrics import f1_score, accuracy_score

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    
    F1_score = f1_score(pred_flat, labels_flat, average='macro')
    
    return accuracy_score(pred_flat, labels_flat), F1_score

# %%
import random
from tqdm import tqdm_notebook
device = 'cuda'
epochs = 10

param_optimizer = list(BERT_SA.named_parameters())
no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]

optimizer = AdamW(optimizer_grouped_parameters, lr=1e-5, correct_bias=False)


for epoch_i in range(0, epochs):
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    total_loss = 0
    BERT_SA.train()
    train_accuracy = 0
    nb_train_steps = 0
    train_f1 = 0
    
    for step, batch in tqdm_notebook(enumerate(train_dataloader)):
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        BERT_SA.zero_grad()
        outputs = BERT_SA(b_input_ids, 
            token_type_ids=None, 
            attention_mask=b_input_mask, 
            labels=b_labels)
        loss = outputs[0]
        total_loss += loss.item()
        
        logits = outputs[1].detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        tmp_train_accuracy, tmp_train_f1 = flat_accuracy(logits, label_ids)
        train_accuracy += tmp_train_accuracy
        train_f1 += tmp_train_f1
        nb_train_steps += 1
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(BERT_SA.parameters(), 1.0)
        optimizer.step()
        
    avg_train_loss = total_loss / len(train_dataloader)
    print(" Accuracy: {0:.4f}".format(train_accuracy/nb_train_steps))
    print(" F1 score: {0:.4f}".format(train_f1/nb_train_steps))
    print(" Average training loss: {0:.4f}".format(avg_train_loss))

    print("Running Validation...")
    BERT_SA.eval()
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0
    eval_f1 = 0
    for batch in tqdm_notebook(val_dataloader):

        batch = tuple(t.to(device) for t in batch)

        b_input_ids, b_input_mask, b_labels = batch

        with torch.no_grad():
            outputs = BERT_SA(b_input_ids, 
            token_type_ids=None, 
            attention_mask=b_input_mask)
            logits = outputs[0]
            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()

            tmp_eval_accuracy, tmp_eval_f1 = flat_accuracy(logits, label_ids)

            eval_accuracy += tmp_eval_accuracy
            eval_f1 += tmp_eval_f1
            nb_eval_steps += 1
    print(" Accuracy: {0:.4f}".format(eval_accuracy/nb_eval_steps))
    print(" F1 score: {0:.4f}".format(eval_f1/nb_eval_steps))
print("Training complete!")
# Out:
# ======== Epoch 1 / 10 ========
# Training...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.8370
#  F1 score: 0.8262
#  Average training loss: 0.3511
# Running Validation...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=51.0), HTML(value='')))
#  Accuracy: 0.9118
#  F1 score: 0.9087
# ======== Epoch 2 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9071
#  F1 score: 0.9025
#  Average training loss: 0.2348
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=51.0), HTML(value='')))
#  Accuracy: 0.9167
#  F1 score: 0.9131
# ======== Epoch 3 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9261
#  F1 score: 0.9223
#  Average training loss: 0.1954
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=51.0), HTML(value='')))
#  Accuracy: 0.9148
#  F1 score: 0.9113
# ======== Epoch 4 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9390
#  F1 score: 0.9358
#  Average training loss: 0.1662
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=51.0), HTML(value='')))
#  Accuracy: 0.9167
#  F1 score: 0.9138
# ======== Epoch 5 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9510
#  F1 score: 0.9482
#  Average training loss: 0.1443
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=51.0), HTML(value='')))
#  Accuracy: 0.9148
#  F1 score: 0.9113
# ======== Epoch 6 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9587
#  F1 score: 0.9566
#  Average training loss: 0.1271
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=51.0), HTML(value='')))
#  Accuracy: 0.9167
#  F1 score: 0.9127
# ======== Epoch 7 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9645
#  F1 score: 0.9625
#  Average training loss: 0.1099
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=51.0), HTML(value='')))
#  Accuracy: 0.9142
#  F1 score: 0.9103
# ======== Epoch 8 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#  Accuracy: 0.9700
#  F1 score: 0.9685
#  Average training loss: 0.0983
# Running Validation...
# HBox(children=(FloatProgress(value=0.0, max=51.0), HTML(value='')))
#  Accuracy: 0.9056
#  F1 score: 0.9011
# ======== Epoch 9 / 10 ========
# Training...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
